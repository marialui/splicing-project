# %%
import pandas as pd
import os
import glob
import numpy as np

# %%
# !ls MXE
# Out:
# DE_novo_SIG-bAmy_VS_CTR-MXE-JC.txt  DE_novo_SIG-CBNR20-bAmy-vs-bAmy-MXE-JC.txt

# %%
path_to_search = '**/DE_novo_SIG-CBNR20-bAmy-vs-bAmy-*-JC.txt'  # This pattern searches for CSV files in all subdirectories
csv_files = glob.glob(path_to_search, recursive=True)
csv_files
# Out:
# ['MXE/DE_novo_SIG-CBNR20-bAmy-vs-bAmy-MXE-JC.txt',
#  'A5SS/DE_novo_SIG-CBNR20-bAmy-vs-bAmy-A5SS-JC.txt',
#  'RI/DE_novo_SIG-CBNR20-bAmy-vs-bAmy-RI-JC.txt',
#  'A3SS/DE_novo_SIG-CBNR20-bAmy-vs-bAmy-A3SS-JC.txt',
#  'SE/DE_novo_SIG-CBNR20-bAmy-vs-bAmy-SE-JC.txt']

# %%
for ev in csv_files:
# Read the file while skipping the first two columns
    df_tmp = pd.read_csv(ev, sep='\t', usecols=lambda column: column not in [ 'Unnamed: 0','ID'])
    print(df_tmp.columns[0:12])
    #print(df_tmp.head())
    clas=ev.split('/')[0]
    #print(clas)
    df_tmp['Class']=clas
    if clas=='MXE':
        index_names=['Class']+list(df_tmp.columns[0:12])
        #print(df_tmp.columns)
        df_tmp.set_index(index_names, inplace=True)
        prefixes=['FDR','IncLevel1','IncLevel2','IncLevelDifference']
        filtered_columns = [col for col in df_tmp.columns if any(col.startswith(prefix) for prefix in prefixes)]
        df_filtered = df_tmp[filtered_columns]
        DF=df_filtered
    else:
        df_tmp['None']='None'
        df_tmp['None2']='None'
        index_names=['Class']+list(df_tmp.columns[0:10])+['None']+['None2']
        #print(df_tmp.columns)
        df_tmp.set_index(index_names, inplace=True)
        prefixes=['FDR','IncLevel1','IncLevel2','IncLevelDifference']
        filtered_columns = [col for col in df_tmp.columns if any(col.startswith(prefix) for prefix in prefixes)]
        df_filtered = df_tmp[filtered_columns]
        DF=pd.concat([DF, df_filtered])
# Out:
# Index(['GeneID', 'geneSymbol', 'chr', 'strand', '1stExonStart_0base',
#        '1stExonEnd', '2ndExonStart_0base', '2ndExonEnd', 'upstreamES',
#        'upstreamEE', 'downstreamES', 'downstreamEE'],
#       dtype='object')
# Index(['GeneID', 'geneSymbol', 'chr', 'strand', 'longExonStart_0base',
#        'longExonEnd', 'shortES', 'shortEE', 'flankingES', 'flankingEE', 'ID.1',
#        'IJC_SAMPLE_1'],
#       dtype='object')
# Index(['GeneID', 'geneSymbol', 'chr', 'strand', 'riExonStart_0base',
#        'riExonEnd', 'upstreamES', 'upstreamEE', 'downstreamES', 'downstreamEE',
#        'ID.1', 'IJC_SAMPLE_1'],
#       dtype='object')
# Index(['GeneID', 'geneSymbol', 'chr', 'strand', 'longExonStart_0base',
#        'longExonEnd', 'shortES', 'shortEE', 'flankingES', 'flankingEE', 'ID.1',
#        'IJC_SAMPLE_1'],
#       dtype='object')
# Index(['GeneID', 'geneSymbol', 'chr', 'strand', 'exonStart_0base', 'exonEnd',
#        'upstreamES', 'upstreamEE', 'downstreamES', 'downstreamEE', 'ID.1',
#        'IJC_SAMPLE_1'],
#       dtype='object')

# %%
# Assuming 'df' is your DataFrame
DF.index = DF.index.set_names(['Class', 'GeneID', 'geneSymbol', 'chr', 'strand', 'coho1',
       'coho2', 'coho3', 'coho4', 'coho5',
       'coho6', 'coho7', 'coho8'])

# %%
DF.to_csv('DE_novo_splicing_events_CBNR20_bAmy-vs-bAmy.txt',sep='\t')

# %%
#DF.index

# %%
DF
# Out:
#                                                                                                                                         FDR  \
# Class GeneID          geneSymbol             chr   strand coho1    coho2    coho3    coho4    coho5    coho6    coho7    coho8
# MXE   ENSG00000198089 SFI1                   chr22 +      31550253 31550348 31561289 31561392 31546860 31546971 31573057 31573214  0.030853
#       ENSG00000130818 ZNF426                 chr19 -      9533839  9533966  9535187  9535279  9532844  9532925  9536207  9536356   0.000750
#       ENSG00000185513 L3MBTL1                chr20 +      43530283 43530419 43532772 43532924 43529202 43529368 43533341 43533418  0.006212
#       ENSG00000033627 ATP6V0A1               chr17 +      42468009 42468107 42470089 42470218 42466428 42466507 42477656 42477742  0.000492
#       ENSG00000170175 CHRNB1                 chr17 +      7448578  7448788  7454296  7454520  7447502  7447650  7455283  7455456   0.009180
# ...                                                                                                                                     ...
# SE    ENSG00000165392 WRN                    chr8  +      31090464 31090536 31088889 31088965 31090833 31090942 None     None      0.023385
#       ENSG00000035403 VCL                    chr10 +      74077701 74077748 74074742 74074903 74082453 74082544 None     None      0.045004
#       ENSG00000265479 DTX2P1-UPK3BP1-PMS2P11 chr7  +      77042229 77042342 77041976 77042063 77043594 77043775 None     None      0.049608
#       ENSG00000289143 NaN                    chr10 -      48031375 48031564 48030937 48031006 48050281 48050421 None     None      0.034035
#       ENSG00000197111 PCBP2                  chr12 +      53467804 53468281 53467220 53467293 53468779 53468832 None     None      0.014940
#
#                                                                                                                                      IncLevel1  \
# Class GeneID          geneSymbol             chr   strand coho1    coho2    coho3    coho4    coho5    coho6    coho7    coho8
# MXE   ENSG00000198089 SFI1                   chr22 +      31550253 31550348 31561289 31561392 31546860 31546971 31573057 31573214    0.861,1.0
#       ENSG00000130818 ZNF426                 chr19 -      9533839  9533966  9535187  9535279  9532844  9532925  9536207  9536356       0.0,0.0
#       ENSG00000185513 L3MBTL1                chr20 +      43530283 43530419 43532772 43532924 43529202 43529368 43533341 43533418  0.342,0.065
#       ENSG00000033627 ATP6V0A1               chr17 +      42468009 42468107 42470089 42470218 42466428 42466507 42477656 42477742   0.904,0.75
#       ENSG00000170175 CHRNB1                 chr17 +      7448578  7448788  7454296  7454520  7447502  7447650  7455283  7455456     0.0,0.222
# ...                                                                                                                                        ...
# SE    ENSG00000165392 WRN                    chr8  +      31090464 31090536 31088889 31088965 31090833 31090942 None     None          1.0,1.0
#       ENSG00000035403 VCL                    chr10 +      74077701 74077748 74074742 74074903 74082453 74082544 None     None          0.0,0.0
#       ENSG00000265479 DTX2P1-UPK3BP1-PMS2P11 chr7  +      77042229 77042342 77041976 77042063 77043594 77043775 None     None       0.459,0.41
#       ENSG00000289143 NaN                    chr10 -      48031375 48031564 48030937 48031006 48050281 48050421 None     None        1.0,0.895
#       ENSG00000197111 PCBP2                  chr12 +      53467804 53468281 53467220 53467293 53468779 53468832 None     None        1.0,0.959
#
#                                                                                                                                      IncLevel2  \
# Class GeneID          geneSymbol             chr   strand coho1    coho2    coho3    coho4    coho5    coho6    coho7    coho8
# MXE   ENSG00000198089 SFI1                   chr22 +      31550253 31550348 31561289 31561392 31546860 31546971 31573057 31573214   0.57,0.805
#       ENSG00000130818 ZNF426                 chr19 -      9533839  9533966  9535187  9535279  9532844  9532925  9536207  9536356   0.294,0.306
#       ENSG00000185513 L3MBTL1                chr20 +      43530283 43530419 43532772 43532924 43529202 43529368 43533341 43533418  0.722,0.666
#       ENSG00000033627 ATP6V0A1               chr17 +      42468009 42468107 42470089 42470218 42466428 42466507 42477656 42477742      1.0,1.0
#       ENSG00000170175 CHRNB1                 chr17 +      7448578  7448788  7454296  7454520  7447502  7447650  7455283  7455456   0.938,0.667
# ...                                                                                                                                        ...
# SE    ENSG00000165392 WRN                    chr8  +      31090464 31090536 31088889 31088965 31090833 31090942 None     None        1.0,0.615
#       ENSG00000035403 VCL                    chr10 +      74077701 74077748 74074742 74074903 74082453 74082544 None     None      0.055,0.154
#       ENSG00000265479 DTX2P1-UPK3BP1-PMS2P11 chr7  +      77042229 77042342 77041976 77042063 77043594 77043775 None     None      0.265,0.213
#       ENSG00000289143 NaN                    chr10 -      48031375 48031564 48030937 48031006 48050281 48050421 None     None      0.818,0.696
#       ENSG00000197111 PCBP2                  chr12 +      53467804 53468281 53467220 53467293 53468779 53468832 None     None      0.968,0.708
#
#                                                                                                                                    IncLevelDifference
# Class GeneID          geneSymbol             chr   strand coho1    coho2    coho3    coho4    coho5    coho6    coho7    coho8
# MXE   ENSG00000198089 SFI1                   chr22 +      31550253 31550348 31561289 31561392 31546860 31546971 31573057 31573214               0.243
#       ENSG00000130818 ZNF426                 chr19 -      9533839  9533966  9535187  9535279  9532844  9532925  9536207  9536356               -0.300
#       ENSG00000185513 L3MBTL1                chr20 +      43530283 43530419 43532772 43532924 43529202 43529368 43533341 43533418              -0.490
#       ENSG00000033627 ATP6V0A1               chr17 +      42468009 42468107 42470089 42470218 42466428 42466507 42477656 42477742              -0.173
#       ENSG00000170175 CHRNB1                 chr17 +      7448578  7448788  7454296  7454520  7447502  7447650  7455283  7455456               -0.692
# ...                                                                                                                                               ...
# SE    ENSG00000165392 WRN                    chr8  +      31090464 31090536 31088889 31088965 31090833 31090942 None     None                   0.193
#       ENSG00000035403 VCL                    chr10 +      74077701 74077748 74074742 74074903 74082453 74082544 None     None                  -0.104
#       ENSG00000265479 DTX2P1-UPK3BP1-PMS2P11 chr7  +      77042229 77042342 77041976 77042063 77043594 77043775 None     None                   0.196
#       ENSG00000289143 NaN                    chr10 -      48031375 48031564 48030937 48031006 48050281 48050421 None     None                   0.191
#       ENSG00000197111 PCBP2                  chr12 +      53467804 53468281 53467220 53467293 53468779 53468832 None     None                   0.142
#
# [528 rows x 4 columns]
