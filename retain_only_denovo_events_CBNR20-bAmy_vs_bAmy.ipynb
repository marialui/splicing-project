# %%
# !ls
# Out:
# A3SS
# A5SS
# common_between_comparisons.ipynb
# common_NOT-SIG-splicing_events.txt
# common_SIG-splicing_events.txt
# De_novo_comparison-events-JC.ipynb
# De_novo_merge-events-bAmy_VS_CTR.ipynb
# De_novo_merge-events-CBNR20-bAmy-vs-bAmy.ipynb
# De_novo_merge-NOT-SIG-events-bAmy_VS_CTR.ipynb
# De_novo_merge-NOT-SIG-events-CBNR20-bAmy-vs-bAmy.ipynb
# DE_novo_NOT-SIG-splicing_events_bAmy_VS_CTR.txt
# DE_novo_NOT-SIG-splicing_events_CBNR20_bAmy-vs-bAmy.txt
# DE_novo_splicing_events_bAmy_VS_CTR.txt
# DE_novo_splicing_events_CBNR20-bAmy_vs_bAmy.txt
# Figure1_annotated-and-denovo.ipynb
# MXE
# NOT-SIG-splicing_events_bAmy_VS_CTR.txt
# NOT-SIG-splicing_events_CBNR20-bAmy-vs-bAmy.txt
# retain_only_denovo_events_bAmy_VS_CTR.ipynb
# retain_only_denovo_events_bAmy_VS_CTR-NOT-SIG.ipynb
# retain_only_denovo_events_CBNR20-bAmy_vs_bAmy.ipynb
# retain_only_denovo_events_CBNR20-bAmy_vs_bAmy-NOT-SIG.ipynb
# RI
# SE
# splicing_events_bAmy_VS_CTR.txt
# splicing_events_CBNR20-bAmy-vs-bAmy.txt

# %%
import pandas as pd
import numpy as np

# %%
df_denovo=pd.read_csv('DE_novo_splicing_events_CBNR20-bAmy_vs_bAmy.txt',sep='\t')

# %%
# Convert 'coho7' and 'coho8' to integers, handling NaN values
df_denovo['coho7'] = df_denovo['coho7'].fillna(0).astype(int)  # Fill NaN with 0 and convert to int
df_denovo['coho8'] = df_denovo['coho8'].fillna(0).astype(int)  # Fill NaN with 0 and convert to int

# %%
df_denovo
# Out:
#     Class           GeneID              geneSymbol    chr strand     coho1  \
# 0     MXE  ENSG00000198089                    SFI1  chr22      +  31550253
# 1     MXE  ENSG00000130818                  ZNF426  chr19      -   9533839
# 2     MXE  ENSG00000185513                 L3MBTL1  chr20      +  43530283
# 3     MXE  ENSG00000033627                ATP6V0A1  chr17      +  42468009
# 4     MXE  ENSG00000170175                  CHRNB1  chr17      +   7448578
# ..    ...              ...                     ...    ...    ...       ...
# 523    SE  ENSG00000165392                     WRN   chr8      +  31090464
# 524    SE  ENSG00000035403                     VCL  chr10      +  74077701
# 525    SE  ENSG00000265479  DTX2P1-UPK3BP1-PMS2P11   chr7      +  77042229
# 526    SE  ENSG00000289143                     NaN  chr10      -  48031375
# 527    SE  ENSG00000197111                   PCBP2  chr12      +  53467804
#
#         coho2     coho3     coho4     coho5     coho6     coho7     coho8  \
# 0    31550348  31561289  31561392  31546860  31546971  31573057  31573214
# 1     9533966   9535187   9535279   9532844   9532925   9536207   9536356
# 2    43530419  43532772  43532924  43529202  43529368  43533341  43533418
# 3    42468107  42470089  42470218  42466428  42466507  42477656  42477742
# 4     7448788   7454296   7454520   7447502   7447650   7455283   7455456
# ..        ...       ...       ...       ...       ...       ...       ...
# 523  31090536  31088889  31088965  31090833  31090942         0         0
# 524  74077748  74074742  74074903  74082453  74082544         0         0
# 525  77042342  77041976  77042063  77043594  77043775         0         0
# 526  48031564  48030937  48031006  48050281  48050421         0         0
# 527  53468281  53467220  53467293  53468779  53468832         0         0
#
#           FDR    IncLevel1    IncLevel2  IncLevelDifference
# 0    0.030853    0.861,1.0   0.57,0.805               0.243
# 1    0.000750      0.0,0.0  0.294,0.306              -0.300
# 2    0.006212  0.342,0.065  0.722,0.666              -0.490
# 3    0.000492   0.904,0.75      1.0,1.0              -0.173
# 4    0.009180    0.0,0.222  0.938,0.667              -0.692
# ..        ...          ...          ...                 ...
# 523  0.023385      1.0,1.0    1.0,0.615               0.193
# 524  0.045004      0.0,0.0  0.055,0.154              -0.104
# 525  0.049608   0.459,0.41  0.265,0.213               0.196
# 526  0.034035    1.0,0.895  0.818,0.696               0.191
# 527  0.014940    1.0,0.959  0.968,0.708               0.142
#
# [528 rows x 17 columns]

# %%
coho=list(df_denovo.columns[1:13])
# Collapse only the specified columns in 'coho' into a single string
df_denovo['collapsed'] = df_denovo[coho].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
# Strip ' nan' from the 'collapsed' column
# Strip ' nan' only at the end of the string in the 'collapsed' column
# Strip multiple occurrences of ' nan' at the end of the string in the 'collapsed' column
df_denovo['collapsed'] = df_denovo['collapsed'].str.replace(r'(\s?0)+$', '', regex=True)

# %%
df_denovo['DE-NOVO']=False

# %%
df_denovo.at[489,'collapsed']
# Out:
# 'ENSG00000107862 GBF1 chr10 + 102368217 102368454 102367477 102367560 102369210 102369387'

# %%
#for classe in df_denovo['Class'].unique():
#    novel_path='15_10_2024_DENOVO-output_rMATS_bAmy-vs-CTR/fromGTF.novelSpliceSite.%s.txt'%(classe)
#    Ndf=pd.read_csv(novel_path,sep='\t',index_col='ID')
#    Ndf['collapsed'] = Ndf.apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
#    for el in Ndf['collapsed']:
#        for i in df_denovo.index:
#            if df_denovo.at[i,'collapsed']==el:
#                df_denovo.at[i,'DE-NOVO']=True

# %%
# Assuming df_denovo is already loaded
for classe in df_denovo['Class'].unique():
    novel_path = f'../24_09_2024_DENOVO-output_rMATS_CBNR20-bAmy-vs-bAmy/fromGTF.novelSpliceSite.{classe}.txt'
    
    # Read the CSV into a DataFrame
    Ndf = pd.read_csv(novel_path, sep='\t', index_col='ID')
    
    # Collapse values of relevant columns into a single string (use specific columns if needed)
    Ndf['collapsed'] = Ndf.astype(str).agg(' '.join, axis=1)
    
    # Use pd.Series.isin() to check for matching collapsed strings
    matched_indices = df_denovo[df_denovo['collapsed'].isin(Ndf['collapsed'])].index
    
    # Set the 'DE-NOVO' column to True for all matching rows
    df_denovo.loc[matched_indices, 'DE-NOVO'] = True

# %%
df_denovo=df_denovo.drop(columns=['collapsed'])
df_denovo[['coho7', 'coho8']] = df_denovo[['coho7', 'coho8']].replace(0, np.nan)
df_denovo.to_csv('splicing_events_CBNR20-bAmy-vs-bAmy.txt',sep='\t',index=False)

# %%
df_denovo
# Out:
#     Class           GeneID              geneSymbol    chr strand     coho1  \
# 0     MXE  ENSG00000198089                    SFI1  chr22      +  31550253
# 1     MXE  ENSG00000130818                  ZNF426  chr19      -   9533839
# 2     MXE  ENSG00000185513                 L3MBTL1  chr20      +  43530283
# 3     MXE  ENSG00000033627                ATP6V0A1  chr17      +  42468009
# 4     MXE  ENSG00000170175                  CHRNB1  chr17      +   7448578
# ..    ...              ...                     ...    ...    ...       ...
# 523    SE  ENSG00000165392                     WRN   chr8      +  31090464
# 524    SE  ENSG00000035403                     VCL  chr10      +  74077701
# 525    SE  ENSG00000265479  DTX2P1-UPK3BP1-PMS2P11   chr7      +  77042229
# 526    SE  ENSG00000289143                     NaN  chr10      -  48031375
# 527    SE  ENSG00000197111                   PCBP2  chr12      +  53467804
#
#         coho2     coho3     coho4     coho5     coho6       coho7       coho8  \
# 0    31550348  31561289  31561392  31546860  31546971  31573057.0  31573214.0
# 1     9533966   9535187   9535279   9532844   9532925   9536207.0   9536356.0
# 2    43530419  43532772  43532924  43529202  43529368  43533341.0  43533418.0
# 3    42468107  42470089  42470218  42466428  42466507  42477656.0  42477742.0
# 4     7448788   7454296   7454520   7447502   7447650   7455283.0   7455456.0
# ..        ...       ...       ...       ...       ...         ...         ...
# 523  31090536  31088889  31088965  31090833  31090942         NaN         NaN
# 524  74077748  74074742  74074903  74082453  74082544         NaN         NaN
# 525  77042342  77041976  77042063  77043594  77043775         NaN         NaN
# 526  48031564  48030937  48031006  48050281  48050421         NaN         NaN
# 527  53468281  53467220  53467293  53468779  53468832         NaN         NaN
#
#           FDR    IncLevel1    IncLevel2  IncLevelDifference  DE-NOVO
# 0    0.030853    0.861,1.0   0.57,0.805               0.243    False
# 1    0.000750      0.0,0.0  0.294,0.306              -0.300    False
# 2    0.006212  0.342,0.065  0.722,0.666              -0.490    False
# 3    0.000492   0.904,0.75      1.0,1.0              -0.173    False
# 4    0.009180    0.0,0.222  0.938,0.667              -0.692    False
# ..        ...          ...          ...                 ...      ...
# 523  0.023385      1.0,1.0    1.0,0.615               0.193     True
# 524  0.045004      0.0,0.0  0.055,0.154              -0.104     True
# 525  0.049608   0.459,0.41  0.265,0.213               0.196     True
# 526  0.034035    1.0,0.895  0.818,0.696               0.191     True
# 527  0.014940    1.0,0.959  0.968,0.708               0.142     True
#
# [528 rows x 18 columns]

# %%
df_denovo[df_denovo['DE-NOVO']]
# Out:
#     Class           GeneID              geneSymbol    chr strand      coho1  \
# 45    MXE  ENSG00000065427                   KARS1  chr16      -   75644282
# 46    MXE  ENSG00000109919                   MTCH2  chr11      -   47622700
# 82   A5SS  ENSG00000034053                   APBA2  chr15      +   29093074
# 83   A5SS  ENSG00000263798                     NaN  chr17      +   47945558
# 84   A5SS  ENSG00000291068                     NaN   chr1      -  223952384
# ..    ...              ...                     ...    ...    ...        ...
# 523    SE  ENSG00000165392                     WRN   chr8      +   31090464
# 524    SE  ENSG00000035403                     VCL  chr10      +   74077701
# 525    SE  ENSG00000265479  DTX2P1-UPK3BP1-PMS2P11   chr7      +   77042229
# 526    SE  ENSG00000289143                     NaN  chr10      -   48031375
# 527    SE  ENSG00000197111                   PCBP2  chr12      +   53467804
#
#          coho2      coho3      coho4      coho5      coho6       coho7  \
# 45    75644462   75645721   75645835   75641563   75641723  75647577.0
# 46    47622726   47625673   47625741   47617316   47618919  47627079.0
# 82    29093226   29093074   29093220   29094277   29094313         NaN
# 83    47945989   47945558   47945612   47946322   47946393         NaN
# 84   223952870  223952667  223952870  223951478  223952291         NaN
# ..         ...        ...        ...        ...        ...         ...
# 523   31090536   31088889   31088965   31090833   31090942         NaN
# 524   74077748   74074742   74074903   74082453   74082544         NaN
# 525   77042342   77041976   77042063   77043594   77043775         NaN
# 526   48031564   48030937   48031006   48050281   48050421         NaN
# 527   53468281   53467220   53467293   53468779   53468832         NaN
#
#           coho8       FDR    IncLevel1    IncLevel2  IncLevelDifference  \
# 45   75647665.0  0.005072  0.126,0.206      0.0,0.0               0.166
# 46   47627127.0  0.029321    0.906,1.0  0.816,0.652               0.219
# 82          NaN  0.003467  0.226,0.074      0.0,0.0               0.150
# 83          NaN  0.003585      1.0,1.0  0.647,0.739               0.307
# 84          NaN  0.044850    1.0,0.875  0.825,0.612               0.219
# ..          ...       ...          ...          ...                 ...
# 523         NaN  0.023385      1.0,1.0    1.0,0.615               0.193
# 524         NaN  0.045004      0.0,0.0  0.055,0.154              -0.104
# 525         NaN  0.049608   0.459,0.41  0.265,0.213               0.196
# 526         NaN  0.034035    1.0,0.895  0.818,0.696               0.191
# 527         NaN  0.014940    1.0,0.959  0.968,0.708               0.142
#
#      DE-NOVO
# 45      True
# 46      True
# 82      True
# 83      True
# 84      True
# ..       ...
# 523     True
# 524     True
# 525     True
# 526     True
# 527     True
#
# [84 rows x 18 columns]
